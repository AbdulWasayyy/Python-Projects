# %% [markdown]
# # 🎧 PDF to Speech Converter (Python Audiobook Generator)
#
# ## 🎯 Overview
# This project converts any pdf document which you are learning or using for your own personal good to a concentration reading into a easy bed to go voice over of the whole book/document
#
# Whether you’re learning, multitasking, or simply too tired to read — this app turns your reading material into audio effortlessly.
#
# ---
#
# ## 🧠 Key Libraries Used
#
# ### 🔹 `PyPDF2`
# [`PyPDF2`](https://pypi.org/project/PyPDF2/) is a pure-Python library for reading and manipulating PDF files.
# It can extract text, merge PDFs, rotate pages, and much more.
#
# In this project, it’s used to:
# - Open and read PDF files in binary mode (`rb`)
# - Iterate through each page
# - Extract text using `page.extract_text()`
#
# **Example:**
# ```python
# from PyPDF2 import PdfReader
#
# reader = PdfReader("sample.pdf")
# for page in reader.pages:
#     text = page.extract_text()
#     print(text)

# %% [markdown]
# ## 💡 Features
#
# 📂 Choose any PDF file from your computer
#
# 🗣️ Converts text into lifelike speech
#
# ⚙️ Works completely offline (no internet or API key needed)
#
# 🎚️ Adjustable voice, speed, and volume
#
# 🖥️ Simple GUI file picker for convenience

# %% [markdown]
# ## 🧩 How It Works
# | Step | Action                                              |
# | ---- | --------------------------------------------------- |
# | 1️⃣  | User selects a PDF using a file dialog              |
# | 2️⃣  | `PyPDF2` extracts text from all pages               |
# | 3️⃣  | `pyttsx3` converts the extracted text into speech   |
# | 4️⃣  | You hear your document read aloud like an audiobook |

# %%
import pyttsx3
import PyPDF2
from tkinter import Tk, filedialog

def select_pdf_file():
    root = Tk()
    root.withdraw()
    file_path = filedialog.askopenfilename(
        title="Select a PDF file",
        filetypes=[("PDF Files", "*.pdf")]
    )
    return file_path

def extract_text_from_pdf(pdf_path):
    with open(pdf_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
        return text

def text_to_speech(text):
    engine = pyttsx3.init()
    engine.setProperty('rate', 170)
    engine.setProperty('volume', 1.0)
    voices = engine.getProperty('voices')
    engine.setProperty('voice', voices[0].id)  # Change index for different voices
    engine.say(text)
    engine.runAndWait()

def main():
    print("📚 PDF to Speech Converter")
    pdf_path = select_pdf_file()
    if pdf_path:
        print(f"Reading: {pdf_path}")
        text = extract_text_from_pdf(pdf_path)
        if text.strip():
            print("🔊 Converting to speech...")
            text_to_speech(text)
            print("✅ Done! Enjoy your audiobook.")
        else:
            print("⚠️ No text found in the PDF.")
    else:
        print("❌ No file selected.")

if __name__ == "__main__":
    main()
